# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
#importing the dataset
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
#to import csv file
netflix_data = pd.read_csv(r"C:\Users\Sowgn\OneDrive\Desktop\pfsd\netflix_titles.csv")

# %%
netflix_data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#head function
#to show top-5 records of the dataset
netflix_data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added      expiry_Date rating   duration  \
# 0  September 25, 2021  August 31, 2021  PG-13     90 min
# 1  September 24, 2021  August 31, 2021  TV-MA  2 Seasons
# ...

# %%
#tail function
#to show bottom-5 records of dataset
netflix_data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added        expiry_Date rating   duration  \
# 8802  November 20, 2019  November 20, 2019      R    158 min
# 8803       July 1, 2019       July 1, 2019  TV-Y7  2 Seasons
# ...

# %%
#shape
#to show no of rows and colums
netflix_data.shape
# Out:
# (8807, 13)

# %%
#size
#to show no of total values(elements) in the dataset
netflix_data.size
# Out:
# 114491

# %%
#colums function
#to show each column name
netflix_data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'expiry_Date', 'rating', 'duration', 'listed_in', 'description',
#        'release_year'],
#       dtype='object')

# %%
#dtypes
#to show the data-type of each column
netflix_data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# expiry_Date     object
# rating          object
# duration        object
# listed_in       object
# description     object
# release_year     int64
# dtype: object

# %%
#info()
#to show indexes,columns,data-type of each column,memory at once
netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   expiry_Date   8797 non-null   object
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  release_year  8807 non-null   int64
# dtypes: int64(1), object(12)
# memory usage: 894.6+ KB

# %%
#value_counts()
netflix_data.value_counts()
# Out:
# show_id  type   title                director             cast                                                                                                                                                                           country                                                 date_added          expiry_Date        rating  duration  listed_in                                         description                                                                                                                                               release_year
# ...

# %%
#nunique()
netflix_data.nunique()
# Out:
# show_id         8807
# type               2
# title           8804
# director        4528
# cast            7692
# country          748
# date_added      1716
# expiry_Date     1711
# rating            17
# duration         220
# listed_in        514
# description     8775
# release_year      74
# dtype: int64

# %%
#duplicate()
netflix_data[netflix_data.duplicated()]#to check row wise and detect the duplicate rows
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, expiry_Date, rating, duration, listed_in, description, release_year]
# Index: []

# %%
netflix_data.drop_duplicates() #to remove the duplicate rows permanently
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#isnull
#to show where null value is present
netflix_data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       expiry_Date  rating  duration  listed_in  description  release_year
# 0           False   False     False      False        False         False
# ...

# %%
#to show the count of null values in the column
netflix_data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# expiry_Date       10
# rating             4
# duration           3
# listed_in          0
# description        0
# release_year       0
# dtype: int64

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
#heat-map
import seaborn as sns #to show null values using heat-map we have to import seaborn library

# %%
#to show null values using heat-map
sns.heatmap(netflix_data.isnull())
# Out:
# <AxesSubplot:>

# %%
#isin(),#str.contains()
#to show all record of a perticular iteam in any column
netflix_data[netflix_data['title'].isin(['Blood & Water'])]
# Out:
#   show_id     type          title director  \
# 1      s2  TV Show  Blood & Water      NaN
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
#
#            date_added      expiry_Date rating   duration  \
# 1  September 24, 2021  August 31, 2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  release_year
# 1  After crossing paths at a party, a Cape Town t...          2021

# %%
#to_datetime(to add new column)
netflix_data['Date_N']=pd.to_datetime(netflix_data['date_added'])

# %%
netflix_data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added      expiry_Date rating   duration  \
# 0  September 25, 2021  August 31, 2021  PG-13     90 min
# 1  September 24, 2021  August 31, 2021  TV-MA  2 Seasons
# ...

# %%
#to counts the occurrence of all individual years date column
netflix_data['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
#bar graph
netflix_data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#groupby(),to group all unique items of a column and show their count
netflix_data.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(netflix_data['type'])
# Out:
# C:\Users\Sowgn\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
#creating new column
netflix_data['year']=netflix_data['Date_N'].dt.year

# %%
netflix_data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added      expiry_Date rating   duration  \
# 0  September 25, 2021  August 31, 2021  PG-13     90 min
# 1  September 24, 2021  August 31, 2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  release_year     Date_N  \
# 0  As her father nears the end of his life, filmm...          2020 2021-09-25
# 1  After crossing paths at a party, a Cape Town t...          2021 2021-09-24
#
# ...

# %%
#filtering
netflix_data[(netflix_data['type']=='Movie')&(netflix_data['year']==2020)]
# Out:
#      show_id   type                                title  \
# 1470   s1471  Movie                     Alaska Is a Drag
# 1471   s1472  Movie                Best of Stand-Up 2020
# 1472   s1473  Movie                         Bobby Jasoos
# 1474   s1475  Movie                        Tarung Sarung
# 1475   s1476  Movie               Too Handsome to Handle
# ...      ...    ...                                  ...
# 8742   s8743  Movie                       Wild Wild West
# 8743   s8744  Movie                             Wildlife
# 8745   s8746  Movie  Willy Wonka & the Chocolate Factory
# 8764   s8765  Movie                           Wyatt Earp
# 8805   s8806  Movie                                 Zoom
#
#                        director  \
# 1470               Shaz Bennett
# 1471                        NaN
# 1472               Samar Shaikh
# 1474            Archie Hekagery
# 1475  Sabrina Rochelle Kalangie
# ...                         ...
# 8742           Barry Sonnenfeld
# ...
